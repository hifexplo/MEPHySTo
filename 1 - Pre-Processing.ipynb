# %% [markdown]
# # Rikola Preprocessing

# %% [markdown]
# Define location of hyperspectral data containing "CalibData" folder:

# %%
MAIN = '/Users/sandra/Documents/Testdata/JupyterTest/'

# %% [markdown]
# Run batch preprocessing of data folder, including lens distortion correction and band coregistration. Results will be stored in "MAIN/reg/". Use either ORB for fast band matching or SIFT for slower, but sometimes more accurate co-registration:

# %%
from M1_SensorSpec_RikPre import *
Preprocess(MAIN, match="ORB", ORBfeatures=1000)
# Out:
# Processing Calib_K00644.hdr
# Saving /Users/sandra/Documents/Testdata/JupyterTest/reg/Calib_K00644reg
# Processing Calib_K00642.hdr
# Saving /Users/sandra/Documents/Testdata/JupyterTest/reg/Calib_K00642reg
# Processing Calib_K00640.hdr
# Saving /Users/sandra/Documents/Testdata/JupyterTest/reg/Calib_K00640reg

# %%
from M1_SensorSpec_RikPre import *
Preprocess(MAIN, match="SIFT",CONTTRESH=0.07)
# Out:
# Processing Calib_K00644.hdr
# Saving /Users/sandra/Documents/Testdata/JupyterTest/reg/Calib_K00644reg
# Processing Calib_K00642.hdr
# Saving /Users/sandra/Documents/Testdata/JupyterTest/reg/Calib_K00642reg
# Processing Calib_K00640.hdr
# Saving /Users/sandra/Documents/Testdata/JupyterTest/reg/Calib_K00640reg
