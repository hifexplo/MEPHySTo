# %% [markdown]
# # Topographic Correction

# %%
from M3_Pre_Topo import *

# %%
filename='/Users/sandra/Documents/Testdata/JupyterTest/georef/Calib_K00012reg_georef.hdr'
DEMw='//Users/sandra/Documents/Testdata/JupyterTest/georef/Calib_K00012reg_georef_DEM.tif'

# %%
topocorr =topo (filename, DEMw, TZ = 1,DTw =[2015,8,26,15,32,55,0],Lat = 50.147912,Lon = 12.633017, METHOD='minnaert', EPSG='EPSG:32633')
# Out:
# calculating slope and aspect
# calculating slope and aspect
# minnaert
# minnaert
# /Users/sandra/Documents/Programming/Pythonscripts/MEPHySTo_Dist/M3_Pre_Topo.py:181: RuntimeWarning: invalid value encountered in multiply
#   ref_c = r_o * np.power(z, K)
# /Users/sandra/Documents/Programming/Pythonscripts/MEPHySTo_Dist/M3_Pre_Topo.py:181: RuntimeWarning: invalid value encountered in multiply
#   ref_c = r_o * np.power(z, K)
# Saving /Users/sandra/Documents/Testdata/JupyterTest/georef/Calib_K00012reg_georef_topocorr_minn
# Saving /Users/sandra/Documents/Testdata/JupyterTest/georef/Calib_K00012reg_georef_topocorr_minn

# %%
imshow(topocorr, bands=(10,20,30))
# Out:
# ImageView object:
#   Display bands       :  (10, 20, 30)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 170.31174031960506]
#     G: [0.0, 185.77622776881375]
#     B: [0.0, 175.18823556948908]
# ImageView object:
#   Display bands       :  (10, 20, 30)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 170.31174031960506]
#     G: [0.0, 185.77622776881375]
#     B: [0.0, 175.18823556948908]
